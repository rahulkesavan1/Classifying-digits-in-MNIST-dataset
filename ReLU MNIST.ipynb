# %%
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Running the neural network file
# %run network.ipynb

# %%
#Function to convert integer output to numpy vector output
def vectorized_result(j):
    e = np.zeros((10, 1))
    e[j] = 1.0
    return e

# %%
#unpacking MNIST data
with open(r'C:\Users\rahul\Desktop\Projects\Neural Netowrks MNIST\neural-networks-and-deep-learning-master\data\mnist.pkl', 'rb') as f:
    tr_d, va_d, te_d = pd.read_pickle(f)

# %%
training_inputs = [np.reshape(x, (784, 1)) for x in tr_d[0]]
training_results = [vectorized_result(y) for y in tr_d[1]]
training_data = list(zip(training_inputs, training_results))
validation_inputs = [np.reshape(x, (784, 1)) for x in va_d[0]]
validation_data = list(zip(validation_inputs, va_d[1]))
test_inputs = [np.reshape(x, (784, 1)) for x in te_d[0]]
test_data = list(zip(test_inputs, te_d[1]))

# %%
#Initializing Nettwork with ReLU activation neurons
relu_net = ReLU_Network([784,100,10], cost = ReLU_QuadraticCost)

# %%
#Implimenting stochastic gradient descent using a cross entropy cost, L2 regularisation and monitoring accuracies and costs on training and evaluation data
eval_cost, eval_acc, train_cost, train_acc = relu_net.SGD(training_data, 40, 10, eta = 0.01, lmbda = 1, evaluation_data = test_data, monitor_training_accuracy=True, monitor_training_cost=True, monitor_evaluation_accuracy=True, monitor_evaluation_cost=True)
# Out:
#  Epoch 0 completed
# Cost on training data is: 0.14467088966274638
# Accuracy on training data is: 0.89176
# Cost on evaluation data is: 0.14411892416461017
# Accuracy on evaluation data is: 0.9003
#
#  Epoch 1 completed
# Cost on training data is: 0.1251547142661123
# Accuracy on training data is: 0.90808
# Cost on evaluation data is: 0.12553907902126207
# Accuracy on evaluation data is: 0.9156
#
#  Epoch 2 completed
# Cost on training data is: 0.10338321951315778
# Accuracy on training data is: 0.92446
# Cost on evaluation data is: 0.10569230913778799
# Accuracy on evaluation data is: 0.9293
#
#  Epoch 3 completed
# Cost on training data is: 0.09025463965945534
# Accuracy on training data is: 0.93672
# Cost on evaluation data is: 0.09346929794280759
# Accuracy on evaluation data is: 0.9392
#
#  Epoch 4 completed
# Cost on training data is: 0.08602628307592652
# Accuracy on training data is: 0.93914
# Cost on evaluation data is: 0.09005409127376984
# ...

# %%
plt.subplots(1,2, figsize = (12,5))
plt.subplot(1,2,1)
plt.plot(range(40), train_acc)
plt.plot(range(40), eval_acc)
plt.xlabel('Epoch #')
plt.ylabel('Percentage Accuracy')
plt.title("Accuracy on training data during training (ReLU)")
plt.legend(["Training Data", "Evaluation Data"])

plt.subplot(1,2,2)
plt.plot(range(40), train_cost)
plt.plot(range(40), eval_cost)
plt.legend(["Training Cost", "Evaluation Cost"])
plt.xlabel('Epoch #')
plt.ylabel('Cost')
# Out:
# Text(0, 0.5, 'Cost')
